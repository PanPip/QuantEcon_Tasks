# %% [markdown]
# ## Some simple tasks for ptyon intro

# %%
#Find pi with MC

import numpy as np
counter = 0
for i in range(100000):
    loc = [np.random.uniform() for i in range(2)]
    if np.sqrt(loc[0]**2 + loc[1]**2) <= 1:
        counter += 1
print(counter*4/100000)
# Out:
# 3.15044

# %%
#Plot correlated time series

import numpy as np
import matplotlib.pyplot as plt

N = 100 # Size of TS
α = 0.9 # Dependence
init = 1 # Initial value
Ser = [init]

def GenerateTS(N,alpha):
    Ser = [0]
    for i in range(1,N):
        Ser.append(Ser[i-1]*alpha + np.random.randn())
    return(Ser)

# %%
#Multiple calls

for i in [0,0.98,0.8]:
    r = GenerateTS(200,i)
    plt.plot(r, label='TS with alpha '+str(i))
    plt.legend()
plt.show()

# %%
# %pwd
# Out:
# 'C:\\Users\\illya\\Documents\\QuantEcon'

# %%
#Remembering the work with files

f = open('testing.txt','w+')
f.write('nothing')
f.close

f = open('testing.txt','r')
res = f.read()
f.close
print(res)
# Out:
# nothing

# %%
# Example of numbers formatiing
population = '12345678'
population = f'{int(population):,}'
print(population)
# Out:
# 12,345,678

# %%
#Using zip

countries = ('Japan', 'Korea', 'China')
cities = ('Tokyo', 'Seoul', 'Beijing')
for country, city in zip(countries, cities):
    print(f'The capital of {country} is {city}')
    
zip(countries, cities)
# Out:
# The capital of Japan is Tokyo
# The capital of Korea is Seoul
# The capital of China is Beijing

# %%
# Reminder of all and any functions
bools = False, True, True
all(bools)
any(bools)
# Out:
# True

# %%
# %who int
# Out:
# N	 counter	 init

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %%time
import pandas
a=100**13
# Out:
# Wall time: 1.64 s

# %%
# %%timeit 
a=100
# Out:
# 13.3 ns ± 0.263 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
# Docstrings - explainations of functions if help is called

def f(x):
    """
    This function squares its argument
    """
    return x**2

# %%
# ?f
# Out:
# Signature: f(x)
# Docstring: This function squares its argument
# File:      c:\users\illya\documents\quantecon\<ipython-input-45-a2a74d456be2>
# Type:      function

# %%
f??
# Out:
# Signature: f(x)
# Source:
# def f(x):
#     """
#     This function squares its argument
#     """
#     return x**2
# File:      c:\users\illya\documents\quantecon\<ipython-input-45-a2a74d456be2>
# Type:      function

# %%
str??
# Out:
# Init signature: str(self, /, *args, **kwargs)
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to sys.getdefaultencoding().
# errors defaults to 'strict'.
# Type:           type

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ### Lesson: Python Essentials

# %%
# Task - use zip to compute inner product

x_vals = np.random.randn(50)
y_vals = np.random.randn(50)

s = 0
for a,b in zip(x_vals,y_vals):
   s+= a*b

print(s)
print(x_vals)
# Out:
# 1.0993780899858958
# [ 0.74004114  0.35788961  1.43556163 -0.47345226 -1.17148812 -0.43946106
#   0.53610433 -1.26778048 -1.09063685  0.15627268 -0.12799003  1.11686327
#  -0.79474772 -0.55834373  1.99523543  0.96910058 -0.87518562 -0.18582757
#  -0.516312   -0.25341756 -0.10843907 -1.34401453 -0.62270224 -0.23563759
#  -0.53575596  0.51552477 -0.02598233 -0.15943513 -0.29339962 -0.08271167
#  -0.04608653 -1.40842784 -2.41408727  1.26789727  1.66596206  0.06882729
#  -1.2635453   0.66752596  0.20185082  0.2299433  -1.63403342  0.93155838
#  -0.20950768 -0.67890492 -0.03752119 -1.27932807 -0.26108151 -0.73204115
#  -1.86315948 -0.93958089]

# %%
# Count even in one line

a = sum([not(i % 2) for i in range(100) ])
a
# Out:
# 50

# %%
#Count even pairs

pairs = ((2, 5), (4, 2), (9, 8), (12, 10))

a = sum([not(a[0] % 2) and not(a[1] % 2) for a in pairs])
a
# Out:
# 2

# %%
#Num of capital letters in string
b = 'oLo'
def countCapital(st):
    s = sum([i.upper() == i for i in st])
    return s

countCapital('HeyMate')
# Out:
# 2

# %% [markdown]
# ### Lesson: NumPy

# %% [markdown]
# ![Ex1](img/np_1.png)

# %%
# replacing np.poly1d

import numpy as np

def p(x,coef):
    """
    X - a np vector
    coef - a np vector of coeffs
    """
    
    return sum(np.cumprod(x) * coef)

x = np.array([1,2,3])
coef = np.array([1,0,1])

p(x,coef)
# Out:
# 7

# %% [markdown]
# ![Ex2](img/np_2.png)

# %%
# Speeding up the next code using NumPy
import numpy as np
from numpy.random import uniform

def sample(q):
    a = 0.0
    U = uniform(0, 1)
    for i in range(len(q)):
        if a < U <= a + q[i]:
            return i
        a = a + q[i]

# %%
class discreteRV:
    """
    A simple example sone through class
    """

    def __init__(self,q):
        """
        Initialization and creation of cumsum element
        """
        self.q = q
        self.cumq = np.cumsum(q)
        
    def draw(self,k):
        """
        Outputs k elements from the distribution
        """
        print(self.cumq)
        res = self.cumq.searchsorted(uniform(0,1,size=k))
        return res

# %%
a = discreteRV([0.2,0.1,0.2,0.5])

a.draw(4)
# Out:
# [0.2 0.3 0.5 1. ]
# array([3, 1, 2, 3], dtype=int64)

# %% [markdown]
# ![Ex3](img/np_3.png)

# %% [markdown]
# ![Reference](img/np_4.png)

# %%
#Initial code

class ECDF:

    def __init__(self, observations):
        self.observations = observations

    def __call__(self, x):
        counter = 0.0
        for obs in self.observations:
            if obs <= x:
                counter += 1
        return counter / len(self.observations)

# == test == #

samples = [uniform(0, 1) for i in range(10)]
F = ECDF(samples)

print(F(0.5))  # Evaluate ecdf at x = 0.5
# Out:
# 0.7

# %%
#Applied changes

class ECDF:

    def __init__(self, observations):
        self.observations = np.array(observations)

    def __call__(self, x):
        return sum(self.observations <= x)/len(self.observations)

# %%
F = ECDF(samples)

print(F(0.5))  # Evaluate ecdf at x = 0.5
# Out:
# 0.7

# %% [markdown]
# ### Lesson: Matplotlib

# %%
#Example: MATLAB-style API vs Object-oriented API

#MATLAB
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

x = np.linspace(0, 10, 200)
y = np.sin(x)

plt.plot(x, y, 'b-', linewidth=2)
plt.show()

# %%
#Obj-oriented
fig, ax = plt.subplots()
ax.plot(x, y, 'r-', linewidth=2, label='sine function', alpha=0.6)
ax.legend(loc='upper center')
ax.set_yticks([-1, 0, 1])
ax.set_title('Test plot')
plt.show()

# %%
#Another Example
from scipy.stats import norm
from random import uniform

fig, ax = plt.subplots()
x = np.linspace(-4, 4, 150)
for i in range(3):
    m, s = uniform(-1, 1), uniform(1, 2)
    y = norm.pdf(x, loc=m, scale=s)
    current_label = f'$\mu = {m:.2}$'
    ax.plot(x, y, linewidth=2, alpha=0.6, label=current_label)
ax.legend()
plt.show()

# %%
#Subplots
num_rows, num_cols = 3, 2
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 12))
for i in range(num_rows):
    for j in range(num_cols):
        m, s = uniform(-1, 1), uniform(1, 2)
        x = norm.rvs(loc=m, scale=s, size=100)
        axes[i, j].hist(x, alpha=0.6, bins=20)
        t = f'$\mu = {m:.2}, \quad \sigma = {s:.2}$'
        axes[i, j].set(title=t, xticks=[-4, 0, 4], yticks=[])
plt.show()

# %%
# 3D plot

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm


def f(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

xgrid = np.linspace(-3, 3, 50)
ygrid = xgrid
x, y = np.meshgrid(xgrid, ygrid)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x,
                y,
                f(x, y),
                rstride=2, cstride=2,
                cmap=cm.jet,
                alpha=0.7,
                linewidth=0.25)
ax.set_zlim(-0.5, 1.0)
plt.show()

# %% [markdown]
# ![Ex1](img/mpl_1.png)

# %%
#Ex_1

fig, ax = plt.subplots()
x = np.linspace(0, 5, 200)
for θ in np.linspace(0,2,10):
    y = np.cos(np.pi * θ * x) * np.exp(-x)
    ax.plot(x, y, linewidth=2, alpha=0.6, label=current_label)
plt.show()

# %% [markdown]
# ### Lesson: SciPy

# %%
"""
A word or two about the package features.
Then about the root-searching methods.


"""
# Out:
# '\nA word or two about the package features.\nThen about the root-searching methods.\n\n\n'

# %%
from scipy.optimize import newton
from scipy.optimize import bisect
import numpy as np

#The example function
f = lambda x: np.sin(4 * (x - 1/4)) + x + x**20 - 1
x = np.linspace(0, 1, 100)

# %%
# %timeit bisect(f, 0, 1)
# Out:
# 59.4 µs ± 1.04 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit newton(f, 0.2)
# Out:
# 16 µs ± 305 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
#It's the tradeoff between the robustness and the speed of execution
#Many widely used methods are a combination of these two

from scipy.optimize import brentq

# %timeit brentq(f, 0, 1)
# Out:
# 15.1 µs ± 619 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
#Option for the fixed points

from scipy.optimize import fixed_point

fixed_point(lambda x: x**2, 10.0)
# Out:
# array(1.)

# %%
#A way to integrate using SciPy

from scipy.integrate import quad

integral, error = quad(lambda x: x**2, 0, 1)
integral
# Out:
# 0.33333333333333337

# %% [markdown]
# [Method used to cumpute this](https://en.wikipedia.org/wiki/Clenshaw%E2%80%93Curtis_quadrature)

# %% [markdown]
# #### Exercise 1
#
# Write a recursive implementation of the bisection function described below.
# Test it on the function discussed above

# %%
#Ex1

#Original code
def bisect1(f, a, b, tol=10e-5):
    """
    Implements the bisection root finding algorithm, assuming that f is a
    real-valued function on [a, b] satisfying f(a) < 0 < f(b).
    """
    lower, upper = a, b

    while upper - lower > tol:
        middle = 0.5 * (upper + lower)
        # === if root is between lower and middle === #
        if f(middle) > 0:
            lower, upper = lower, middle
        # === if root is between middle and upper  === #
        else:              
            lower, upper = middle, upper

    return 0.5 * (upper + lower)

#Recursive implementation
def bisect(f, lower, upper, tol=10e-5):
    """
    Implements a recursive bisection root finding algorithm, 
    assuming that f is a real-valued function on [a, b] 
    satisfying f(a) < 0 < f(b).
    """
    middle = 0.5 * (upper + lower)
    if f(middle) > 0:
        lower, upper = lower, middle
    else:              
        lower, upper = middle, upper
    if upper - lower > tol:
        return bisect(f,lower,upper,tol)
    else:
        return 0.5 * (upper + lower)

# %%
bisect(f, 0, 1)
# Out:
# 0.408294677734375

# %%
bisect1(f, 0, 1)
# Out:
# 0.408294677734375

# %% [markdown]
# ### Lesson: Numba

# %%
"""
It's a library that uses just in time (JIT) compilation.
"""
#Testing the concepts

import random
import numpy as np
import quantecon as qe

# %%
#The non-vectorized code

qe.util.tic()   # Start timing
n = 100_000
sum = 0
for i in range(n):
    x = random.uniform(0, 1)
    sum += x**2
qe.util.toc()   # End timing
# Out:
# TOC: Elapsed: 0:00:0.06
# 0.0618438720703125

# %%
#Now, the vectorized

qe.util.tic()
n = 100_000
x = np.random.uniform(0, 1, n)
np.sum(x**2)
qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.04
# 0.049468278884887695

# %%
#Unifunc examples

def f(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

grid = np.linspace(-3, 3, 1000)
m = -np.inf

qe.tic()
for x in grid:
    for y in grid:
        z = f(x, y)
        if z > m:
            m = z

qe.toc()
# Out:
# TOC: Elapsed: 0:00:3.85
# 3.8593153953552246

# %%
def f(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

grid = np.linspace(-3, 3, 1000)
x, y = np.meshgrid(grid, grid)

qe.tic()
np.max(f(x, y))
qe.toc()
# Out:
# TOC: Elapsed: 0:00:0.03
# 0.03789520263671875

# %%
# Finally, Numba

import matplotlib.pyplot as plt

#On the example code

def qm(x0, n):
    x = np.empty(n+1)
    x[0] = x0
    for t in range(n):
        x[t+1] = 4 * x[t] * (1 - x[t])
    return x

x = qm(0.1, 250)
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(x, 'b-', lw=2, alpha=0.8)
ax.set_xlabel('time', fontsize=16)
plt.show()

# %%
from numba import jit

qm_numba = jit(qm)  # qm_numba is now a 'compiled' version of qm

# %%
qe.util.tic()
qm(0.1, int(10**5))
time1 = qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.11

# %%
qe.util.tic()
qm_numba(0.1, int(10**5))
time2 = qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.14

# %%
#As we will see, the consecutive executions have higher speed

qe.util.tic()
qm_numba(0.1, int(10**5))
time2 = qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.00

# %%
time1 / time2  # Calculate speed gain
# Out:
# 113.05858440937351

# %%
#We can use simply as a decorator

@jit
def qm(x0, n):
    x = np.empty(n+1)
    x[0] = x0
    for t in range(n):
        x[t+1] = 4 * x[t] * (1 - x[t])
    return x

# %%
#A catch on global variables - Numba treats global variables as constants to ensure stability

#Numba can creeate custom ufuncs

from numba import vectorize

@vectorize
def f_vec(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

grid = np.linspace(-3, 3, 1000)
x, y = np.meshgrid(grid, grid)

np.max(f_vec(x, y))  # Run once to compile

qe.tic()
np.max(f_vec(x, y))
qe.toc()
# Out:
# TOC: Elapsed: 0:00:0.01
# 0.013961553573608398

# %%
#We can compute in parallel, but need to specify the types

@vectorize('float64(float64, float64)', target='parallel')
def f_vec(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

np.max(f_vec(x, y))  # Run once to compile

qe.tic()
np.max(f_vec(x, y))
qe.toc()
# Out:
# TOC: Elapsed: 0:00:0.00
# 0.004985332489013672

# %% [markdown]
# ### Lesson: Other scientifc libraries

# %%
#Cython examples

#Loop implementation for sum of geometric progression in Python

def geo_prog(alpha, n):
    current = 1.0
    sum = current
    for i in range(n):
        current = current * alpha
        sum = sum + current
    return sum

# %%
#Now, the same in Cython

# %load_ext Cython

# %%
# %%cython
# def geo_prog_cython(double alpha, int n):
#     cdef double current = 1.0
#     cdef double sum = current
#     cdef int i
#     for i in range(n):
#         current = current * alpha
#         sum = sum + current
#     return sum

# %%
import quantecon as qe
qe.util.tic()
geo_prog(0.99, int(10**6))
qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.13
# 0.13565444946289062

# %%
qe.util.tic()
geo_prog_cython(0.99, int(10**6))
qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.04
# 0.04686379432678223

# %%
#Joblib - Python library for caching and parallelization

#Using it one can save the results of computations, for example, wheh wanting to restart the Kernel

#Example of how one can cache the results to use them later
from joblib import Memory

memory = Memory(location='./joblib_cache')

@memory.cache
def qm(x0, n):
    x = np.empty(n+1)
    x[0] = x0
    for t in range(n):
        x[t+1] = 4 * x[t] * (1 - x[t])
    return np.mean(x < 0.1)

# %%
qe.util.tic()
n = int(1e7)
qm(0.2, n)
qe.util.toc()
# Out:
# ________________________________________________________________________________
# [Memory] Calling __main__-C%3A-Users-illya-Documents-QuantEcon-QuantEcon_Tasks-__ipython-input__.qm...
# qm(0.2, 10000000)
# _______________________________________________________________qm - 8.2s, 0.1min
# TOC: Elapsed: 0:00:8.30
# 8.305789232254028

# %%
qe.util.tic()
n = int(1e7)
qm(0.2, n)
qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.00
# 0.0019290447235107422

# %% [markdown]
# ##### Links for Fortran Guides to learn
#
# [Link1](http://nbviewer.jupyter.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-6A-Fortran-and-C.ipynb)
#
# [Link2](http://nbviewer.jupyter.org/github/mgaitan/fortran_magic/blob/master/documentation.ipynb)

# %% [markdown]
# ![This](img/else_1.png)

# %%
#Ex1

# Let  "0"=High; "1"= Low 

#Matrix of states
state = np.array([[0.8, 0.2],[0.1, 0.9]])
#Probability of going to state 1 (from state 0 and 1)
p = np.array([0.2, 0.9])
N = 100000

def simple_markov(p, N):
    time_in_low = 0
    state = 0
    for i in range(N):
        new_state = np.random.binomial(1, p[state])
        if np.random.binomial(1, p[state]) == 1:
            time_in_low += 1
        state = new_state
    return time_in_low/N

print('Appr. time in low: ',simple_markov(p, N) )
# Out:
# Appr. time in low:  0.66895

# %%
#Rewriting in Numba

from numba import jit

simple_markov_numba = jit(simple_markov)
res = []

# %%
qe.util.tic()
simple_markov(p, N)
qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.45
# 0.45872998237609863

# %%
qe.util.tic()
simple_markov_numba(p, N)
qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.13
# 0.13835620880126953

# %%
#Now, the Cython version

# %load_ext Cython
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
# %%cython
# import numpy as np
# '''
# def geo_prog_cython(double alpha, int n):
#     cdef double current = 1.0
#     cdef double sum = current
#     cdef int i
#     for i in range(n):
#         current = current * alpha
#         sum = sum + current
#     return sum
# '''
#
# def simple_markov_cython(double p, double q, int N):
#     cdef int time_in_low = 0
#     cdef int state = 0
#     cdef int new_state = 0
#     for i in range(N):
#         if state == 0:
#             new_state = np.random.binomial(1, p)
#         else:
#             new_state = np.random.binomial(1, q)
#         if new_state == 1:
#             time_in_low += 1
#         state = new_state
#     return time_in_low/N

# %%
qe.util.tic()
simple_markov_cython(0.2, 0.9, N)
qe.util.toc()
# Out:
# TOC: Elapsed: 0:00:0.19
# 0.19251537322998047

# %% [markdown]
# Results:
#
# * Vanilla: 0.46
# * Numba: 0.14
# * Cython: 0.19
